# %% [markdown]
# # Prioritize Delay-Sensitive Traffic Using QOS
# ###### <sup>Use case: Paban Sarma (pasarma@cisco.com); Developed by: Sarah Samuel (sasamuel@cisco.com). </sup>

# %% [markdown]
# Quality of Service (QoS) is the technique of prioritizing traffic flows and providing preferential forwarding for higher-priority packets. The fundamental reason for implementing QoS in your network is to provide better service for certain traffic flows.
#
# There are 3 ways to achieve this on a Service-Provider (SP) network using QoS:
# * Uniform Mode QoS
# * Pipe Mode QoS
# * Short-pipe Mode QoS
#
# This notebook demonstrates uniform mode QoS, whereby the packets of delay-sensitive traffic is routed with high-priority, across the SP network.

# %% [markdown]
# ### NETWORK TOPOLOGY
# This notebook brings up a Service Provider network topology, with 2 Provider-Edge (PE) routers and one Provider (P) router. After the base configuration of OSPF and MPLS is up, QoS is applied on the ingress and egress interfaces of PE and P routers in the network to ensure that delay sensitive traffic such as voice and video are given high priroity.
#
# There are 2 traffic generator ports in this network, which represent 2 Customer Edge (CE) routers. Along with that, there are 2 other CE routers present. Traffic flows from one traffic generator port to the other to simulate customer traffic across the SP network. Ping traffic is also present from CE1 to CE2.
#
# ![Topology](tgn-ospf-mpls.png)
#
# In order to ensure higher priority is provided for video traffic, the customer marks the video traffic packets with certain values in the packet header, in this case the DSCP bits in the IP header are marked for expedited forwarding (ef). The service-provider is informed of this marking so that they can easily give preferential treatment to the marked packets.
#
# In the ingress interface of the SP routers, the traffic packets are classified based on the values marked in the header of the incoming packet and the video traffic is given the highest priority over the other forms of traffic.

# %% [markdown]
# ## Configuration Steps
# * [Bring up emulator session with the base network and configurations](#step1)
# * [Verify the base network configurations](#step2)
# * [Apply the QoS configurations for PE1](#step5)
# * [Apply the QoS configurations on other routers in the MPLS network](#step11)
# * [Start Traffic from TREX Traffic Generator](#step100)
# * [Verify the QoS configurations](#step7)

# %% [markdown]
# ## <a name="step1"></a>Bring up emulator session with the base network and configurations

# %% [markdown]
# `The below cell installs a couple of python packages essential for running the traffic generator. You have to execute the cell below by clicking the play button.`

# %%
# !pip install paramiko
# !pip install paramiko-expect
# Out:
# Collecting paramiko
#   Downloading paramiko-2.7.2-py2.py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 10.6 MB/s eta 0:00:01
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 5.9 MB/s  eta 0:00:01
# Requirement already satisfied: cryptography>=2.5 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from paramiko) (3.4.7)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 10.9 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.4.1 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from bcrypt>=3.1.3->paramiko) (1.15.0)
# Requirement already satisfied: cffi>=1.1 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from bcrypt>=3.1.3->paramiko) (1.14.5)
# Requirement already satisfied: pycparser in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko) (2.20)
# Installing collected packages: pynacl, bcrypt, paramiko
# Successfully installed bcrypt-3.2.0 paramiko-2.7.2 pynacl-1.4.0
# Collecting paramiko-expect
#   Downloading paramiko_expect-0.3.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: paramiko>=1.10.1 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from paramiko-expect) (2.7.2)
# Requirement already satisfied: bcrypt>=3.1.3 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from paramiko>=1.10.1->paramiko-expect) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from paramiko>=1.10.1->paramiko-expect) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from paramiko>=1.10.1->paramiko-expect) (3.4.7)
# Requirement already satisfied: six>=1.4.1 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from bcrypt>=3.1.3->paramiko>=1.10.1->paramiko-expect) (1.15.0)
# Requirement already satisfied: cffi>=1.1 in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from bcrypt>=3.1.3->paramiko>=1.10.1->paramiko-expect) (1.14.5)
# Requirement already satisfied: pycparser in /home/vxr/miniconda3/envs/pyvxr/lib/python3.8/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=1.10.1->paramiko-expect) (2.20)
# Installing collected packages: paramiko-expect
# Successfully installed paramiko-expect-0.3.0

# %% [markdown]
# `In the cell below, the python module SP_tgn contains the code to set up the python environment, the simulated 5-router topology and the linux server according to the network topology diagram, above. The sim.start() API brings up the emulator as per the network topology. Refer the SP_tgn.py file in this repository to have a look at the python module.`

# %%
from SP_tgn import *

sim = Vxr()
sim.no_image_copy=True
sim.clean()
print("Sim clean: Done")
print("Simulation starting. Please wait for the Sim status message. This may take 3-10 minutes.")

try:
    sim.start(cfg)
    status = sim.status()
    print("Sim status: ", status)
except Exception as err:
    print("Sim launch failed (%s)" % str(err))
# Out:
# INFO:pyvxr.vxr:v1.1.0 2021-04-27 09:30 output_dir:vxr.out
# INFO:pyvxr.vxr:bd8e02377cc7:/home/vxr/notebooks/Put-Technology-to-Work/QoS
# WARNING:pyvxr.vxr:Config not specified or not found. Will attempt to release slurm resources if reserved
# INFO:pyvxr.vxr:Extracting vxr version from '/opt/cisco/vxr2/latest/setup.sh' file.
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# 3.8.8 (default, Apr 13 2021, 19:58:26)
# [GCC 7.3.0]
# Sim clean: Done
# Simulation starting. Please wait for the Sim status message. This may take 3-10 minutes.
# INFO:pyvxr.sim:Launch: sim_dir:/nobackup/vxr/pyvxr/lrrf79dilr sim_rel:/opt/cisco/vxr2/latest
# INFO:pyvxr.sim:Stopping previous simulation (if any)
# INFO:pyvxr.sim:Cleaning previous simulation (if any)
# INFO:pyvxr.sim:Starting vxr: 'sim --skiphomecheck -n '
# INFO:pyvxr.sim:Vxr up on host localhost
# INFO:pyvxr.vxr:Getting port vector files for:rce1, rce2, rp1, rpe1, rpe2, trex
# INFO:pyvxr.console:rpe1:wait for XR login prompt (console output captured in vxr.out/logs/console.rpe1.log)
# INFO:pyvxr.console:rce2:wait for XR login prompt (console output captured in vxr.out/logs/console.rce2.log)
# INFO:pyvxr.console:rce1:wait for XR login prompt (console output captured in vxr.out/logs/console.rce1.log)
# INFO:pyvxr.console:rpe2:wait for XR login prompt (console output captured in vxr.out/logs/console.rpe2.log)
# INFO:pyvxr.console:rp1:wait for XR login prompt (console output captured in vxr.out/logs/console.rp1.log)
# INFO:pyvxr.console:rp1:entering new XR username 'cisco', password 'cisco123'
# INFO:pyvxr.console:rp1:entering XR username 'cisco', password 'cisco123'
# INFO:pyvxr.console:rpe2:entering new XR username 'cisco', password 'cisco123'
# INFO:pyvxr.bringup:rp1:login successful
# INFO:pyvxr.bringup:rp1:wait for IOS XR RUN state
# INFO:pyvxr.console:rce1:entering new XR username 'cisco', password 'cisco123'
# INFO:pyvxr.bringup:rp1:run state RPs:1 (expected:1) LCs:0 (expected:0)
# INFO:pyvxr.bringup:rp1:all nodes reached IOS XR RUN state
# INFO:pyvxr.console:rp1:applying initial XR config (terminal width, etc)
# INFO:pyvxr.console:rp1:waiting for ztp and cvac to complete
# INFO:pyvxr.console:rpe2:entering XR username 'cisco', password 'cisco123'
# INFO:pyvxr.console:rp1:found ztp directory. Assuming ztp present
# INFO:pyvxr.console:rp1:waiting for ztp to complete
# INFO:pyvxr.console:rp1:ztp done
# INFO:pyvxr.console:rce1:entering XR username 'cisco', password 'cisco123'
# INFO:pyvxr.bringup:rpe2:login successful
# INFO:pyvxr.bringup:rpe2:wait for IOS XR RUN state
# INFO:pyvxr.bringup:rpe2:run state RPs:1 (expected:1) LCs:0 (expected:0)
# INFO:pyvxr.bringup:rpe2:all nodes reached IOS XR RUN state
# INFO:pyvxr.console:rpe2:applying initial XR config (terminal width, etc)
# INFO:pyvxr.console:rpe2:waiting for ztp and cvac to complete
# INFO:pyvxr.console:rpe2:found ztp directory. Assuming ztp present
# INFO:pyvxr.console:rpe2:waiting for ztp to complete
# INFO:pyvxr.bringup:rce1:login successful
# INFO:pyvxr.console:rce2:entering new XR username 'cisco', password 'cisco123'
# INFO:pyvxr.console:rpe2:ztp done
# INFO:pyvxr.bringup:rce1:wait for IOS XR RUN state
# INFO:pyvxr.bringup:rce1:run state RPs:1 (expected:1) LCs:0 (expected:0)
# INFO:pyvxr.bringup:rce1:all nodes reached IOS XR RUN state
# INFO:pyvxr.console:rce1:applying initial XR config (terminal width, etc)
# INFO:pyvxr.console:rce1:waiting for ztp and cvac to complete
# INFO:pyvxr.console:rce1:found ztp directory. Assuming ztp present
# INFO:pyvxr.console:rce1:waiting for ztp to complete
# INFO:pyvxr.console:rce1:ztp done
# INFO:pyvxr.console:rce2:entering XR username 'cisco', password 'cisco123'
# INFO:pyvxr.console:rpe1:entering new XR username 'cisco', password 'cisco123'
# INFO:pyvxr.bringup:rce2:login successful
# INFO:pyvxr.bringup:rce2:wait for IOS XR RUN state
# INFO:pyvxr.console:rpe1:entering XR username 'cisco', password 'cisco123'
# INFO:pyvxr.bringup:rce2:run state RPs:1 (expected:1) LCs:0 (expected:0)
# INFO:pyvxr.bringup:rce2:all nodes reached IOS XR RUN state
# INFO:pyvxr.console:rce2:applying initial XR config (terminal width, etc)
# INFO:pyvxr.console:rce2:waiting for ztp and cvac to complete
# INFO:pyvxr.console:rce2:found ztp directory. Assuming ztp present
# INFO:pyvxr.console:rce2:waiting for ztp to complete
# INFO:pyvxr.console:rce2:ztp done
# INFO:pyvxr.bringup:rpe1:login successful
# INFO:pyvxr.bringup:rpe1:wait for IOS XR RUN state
# INFO:pyvxr.bringup:rpe1:run state RPs:1 (expected:1) LCs:0 (expected:0)
# INFO:pyvxr.bringup:rpe1:all nodes reached IOS XR RUN state
# INFO:pyvxr.console:rpe1:applying initial XR config (terminal width, etc)
# INFO:pyvxr.console:rpe1:waiting for ztp and cvac to complete
# INFO:pyvxr.console:rpe1:found ztp directory. Assuming ztp present
# INFO:pyvxr.console:rpe1:waiting for ztp to complete
# INFO:pyvxr.console:rpe1:ztp done
# INFO:pyvxr.vxr:Setting up ssh tunnels on host 'localhost'
# INFO:pyvxr.ssh_tunnel:Configure mgmt interfaces before setting up ssh tunnels
# INFO:pyvxr.console:rp1:need to configure mgmt interface MgmtEth0/RP0/CPU0/0
# INFO:pyvxr.console:rpe2:need to configure mgmt interface MgmtEth0/RP0/CPU0/0
# INFO:pyvxr.console:rce1:need to configure mgmt interface MgmtEth0/RP0/CPU0/0
# INFO:pyvxr.console:rce2:need to configure mgmt interface MgmtEth0/RP0/CPU0/0
# INFO:pyvxr.console:rpe1:need to configure mgmt interface MgmtEth0/RP0/CPU0/0
# INFO:pyvxr.console:trex:login root/cisco123
# INFO:pyvxr.console:trex:sending return
# INFO:pyvxr.console:trex:entering linux username 'root'
# INFO:pyvxr.console:trex:entering linux password 'cisco123'
# INFO:pyvxr.console:trex:reached Linux prompt. Reseting console
# INFO:pyvxr.console:rp1:mgmt interface configuration applied
# INFO:pyvxr.console:rpe2:mgmt interface configuration applied
# INFO:pyvxr.console:rce1:mgmt interface configuration applied
# INFO:pyvxr.console:rce2:mgmt interface configuration applied
# INFO:pyvxr.console:rpe1:mgmt interface configuration applied
# INFO:pyvxr.console:trex:mgmt interface up (ip:192.168.254.153)
# INFO:pyvxr.console:rp1:mgmt interface up (ip:192.168.254.34)
# INFO:pyvxr.console:rce1:mgmt interface up (ip:192.168.254.15)
# INFO:pyvxr.console:rpe2:mgmt interface up (ip:192.168.254.157)
# INFO:pyvxr.console:rce2:mgmt interface up (ip:192.168.254.91)
# INFO:pyvxr.console:rpe1:mgmt interface up (ip:192.168.254.227)
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# INFO:pyvxr.vxr_session:Starting a local bash session for user:vxr
# INFO:pyvxr.ssh_tunnel:rce1:Setting up ssh tunnels for port(s) [22, 830]
# INFO:pyvxr.ssh_tunnel:rce2:Setting up ssh tunnels for port(s) [22, 830]
# INFO:pyvxr.ssh_tunnel:rp1:Setting up ssh tunnels for port(s) [22, 830]
# INFO:pyvxr.ssh_tunnel:rpe2:Setting up ssh tunnels for port(s) [22, 830]
# INFO:pyvxr.ssh_tunnel:trex:Setting up ssh tunnels for port(s) [21, 22, 23, 50, 53, 80]
# INFO:pyvxr.ssh_tunnel:rpe1:Setting up ssh tunnels for port(s) [22, 830]
# INFO:pyvxr.bringup:rce1:applying XR config
# INFO:pyvxr.bringup:rce2:applying XR config
# INFO:pyvxr.bringup:rp1:applying XR config
# INFO:pyvxr.bringup:rpe1:applying XR config
# INFO:pyvxr.bringup:rpe2:applying XR config
# INFO:pyvxr.vxr:Sim up
# INFO:pyvxr.vxr:Getting sim status from localhost:/nobackup/vxr/pyvxr/lrrf79dilr
# Sim status:  {'localhost': 'running'}

# %% [markdown]
# `Play the cell below to obtain the telnet and ssh IP-addresses and ports to access the devices.`

# %%
print('Consoles can be reached by:')
print('P1: ', get_telnet_cmd(sim, 'rp1'), '\nP2: ', get_telnet_cmd(sim, 'rp2'), '\nPE1: ', get_telnet_cmd(sim, 'rpe1'), '\nPE2: ', get_telnet_cmd(sim, 'rpe2'), '\nTGN: ', get_telnet_cmd(sim, 'trex'))
print('or better:')
print('P1: ', get_ssh_cmd(sim, 'rp1'), '\nP2: ', get_ssh_cmd(sim, 'rp2'), '\nPE1: ', get_ssh_cmd(sim, 'rpe1'), '\nPE2: ', get_ssh_cmd(sim, 'rpe2'), '\nTGN: ', get_ssh_cmd(sim, 'trex', 'True'))
print('The password is cisco123')
# Out:
# Consoles can be reached by:
# P1:  telnet 172.17.0.2 35212
# PE1:  telnet 172.17.0.2 34457
# PE2:  telnet 172.17.0.2 38917
# CE1:  telnet 172.17.0.2 35211
# CE2:  telnet 172.17.0.2 41832
# TGN:  telnet 172.17.0.2 36745
# or better:
# P1:  ssh cisco@172.17.0.2 -p61003
# PE1:  ssh cisco@172.17.0.2 -p62899
# PE2:  ssh cisco@172.17.0.2 -p63082
# CE1:  ssh cisco@172.17.0.2 -p63621
# CE2:  ssh cisco@172.17.0.2 -p60991
# TGN:  ssh root@172.17.0.2 -p62275
# The password is cisco123

# %% [markdown]
# `The cell below accesses the telnet consoles of the routers so that we can apply the required QoS policies from this notebook.`

# %%
ports = sim.ports()
loginpe1 = telnetlib.Telnet(str(ports['rpe1']['HostAgent']) , str(ports['rpe1']['serial0']))
loginp1 = telnetlib.Telnet(str(ports['rp1']['HostAgent']) , str(ports['rp1']['serial0']))
loginp2 = telnetlib.Telnet(str(ports['rp2']['HostAgent']) , str(ports['rp2']['serial0']))
loginpe2 = telnetlib.Telnet(str(ports['rpe2']['HostAgent']) , str(ports['rpe2']['serial0']))
trexipaddress = str(ports['trex']['HostAgent'])
trexport = str(ports['trex']['xr_redir22'])

# %% [markdown]
# ## <a name="step8"></a>Verify the base network configurations

# %% [markdown]
# `Ensure the basic reachability across the network by checking that the routing protocol (OSPF) and MPLS is up with the below commands`

# %%
print("Please wait. It may take 4-5 seconds to retrieve the information from the telnet console.")
loginp1.write(('''
sh version
show ip ospf nei
show mpls ldp interface
show mpls ldp bindings brief
show run mpls ldp
show mpls ldp neigh br
show ip route
''').encode('ascii'))
line = loginp1.read_until(b'/r/n',4)
print(line.decode())
# Out:
# Please wait. It may take 4-5 seconds to retrieve the information from the telnet console.
#
# br
# show ip route
# RP/0/RP0/CPU0:P1#sh version
# Tue Apr 27 09:43:12.356 UTC
# Cisco IOS XR Software, Version 7.3.1 LNT
# Copyright (c) 2013-2021 by Cisco Systems, Inc.
#
# Build Information:
#  Built By     : ingunawa
#  Built On     : Fri Feb 26 04:56:31 UTC 2021
#  Build Host   : iox-ucs-020
#  Workspace    : /auto/srcarchive17/prod/7.3.1/8000/ws
#  Version      : 7.3.1
#  Label        : 7.3.1
#
# cisco 8000 (VXR)
# cisco 8201 (VXR) processor with 32GB of memory
# P1 uptime is 12 minutes
# Cisco 8201 1RU Chassis
#
# RP/0/RP0/CPU0:P1#show ip ospf nei
# Tue Apr 27 09:43:12.469 UTC
#
# * Indicates MADJ interface
# # Indicates Neighbor awaiting BFD session up
#
# Neighbors for OSPF 10
#
# Neighbor ID     Pri   State           Dead Time   Address         Interface
# 209.165.200.229 1     FULL/DR         00:00:37    198.51.100.2    FourHundredGigE0/0/0/0
#     Neighbor is up for 00:08:04
# 209.165.200.227 1     FULL/DR         00:00:34    192.0.2.2       FourHundredGigE0/0/0/1
#     Neighbor is up for 00:08:12
#
# Total neighbor count: 2
# RP/0/RP0/CPU0:P1#show mpls ldp interface
# Tue Apr 27 09:43:12.558 UTC
# Interface FourHundredGigE0/0/0/0 (0xf000138)
#    VRF: 'default' (0x60000000)
#    Enabled via config: LDP interface
# Interface FourHundredGigE0/0/0/1 (0xf0001a0)
#    VRF: 'default' (0x60000000)
#    Enabled via config: LDP interface
# RP/0/RP0/CPU0:P1#show mpls ldp bindings brief
# Tue Apr 27 09:43:12.619 UTC
#
# Prefix              Local      Advertised  Remote Bindings
#                     Label        (peers)       (peers)
# ------------------  ---------  ----------  ---------------
# 10.0.0.0/24         24004               2                2
# 10.1.1.0/24         24001               2                2
# 192.0.2.0/24        ImpNull             2                2
# 192.168.254.0/24    ImpNull             2                2
# 198.51.100.0/24     ImpNull             2                2
# 203.0.113.0/24      24005               2                2
# 209.165.200.225/32  ImpNull             2                2
# 209.165.200.227/32  24003               2                2
# 209.165.200.229/32  24000               2                2
# 209.165.201.0/27    24002               2                2
#
# RP/0/RP0/CPU0:P1#show run mpls ldp
# Tue Apr 27 09:43:12.686 UTC
# mpls ldp
#  router-id 209.165.200.225
#  interface FourHundredGigE0/0/0/0
#  !
#  interface FourHundredGigE0/0/0/1
#  !
# !
#
# RP/0/RP0/CPU0:P1#show mpls ldp neigh br
# Tue Apr 27 09:43:13.031 UTC
#
# Peer               GR  NSR  Up Time     Discovery   Addresses     Labels
#                                         ipv4  ipv6  ipv4  ipv6  ipv4   ipv6
# -----------------  --  ---  ----------  ----------  ----------  ------------
# 209.165.200.229:0  N   N    00:07:43    1     0     5     0     10     0
# 209.165.200.227:0  N   N    00:07:40    1     0     5     0     10     0
#
# RP/0/RP0/CPU0:P1#show ip route
# Tue Apr 27 09:43:13.088 UTC
#
# Codes: C - connected, S - static, R - RIP, B - BGP, (>) - Diversion path
#        D - EIGRP, EX - EIGRP external, O - OSPF, IA - OSPF inter area
#        N1 - OSPF NSSA external type 1, N2 - OSPF NSSA external type 2
#        E1 - OSPF external type 1, E2 - OSPF external type 2, E - EGP
#        i - ISIS, L1 - IS-IS level-1, L2 - IS-IS level-2
#        ia - IS-IS inter area, su - IS-IS summary null, * - candidate default
#        U - per-user static route, o - ODR, L - local, G  - DAGR, l - LISP
#        A - access/subscriber, a - Application route
#        M - mobile route, r - RPL, t - Traffic Engineering, (!) - FRR Backup path
#
# Gateway of last resort is not set
#
# O    10.0.0.0/24 [110/2] via 192.0.2.2, 00:07:41, FourHundredGigE0/0/0/1
# O    10.1.1.0/24 [110/2] via 198.51.100.2, 00:07:43, FourHundredGigE0/0/0/0
# C    192.0.2.0/24 is directly connected, 00:08:23, FourHundredGigE0/0/0/1
# L    192.0.2.1/32 is directly connected, 00:08:23, FourHundredGigE0/0/0/1
# C    192.168.254.0/24 is directly connected, 00:09:38, MgmtEth0/RP0/CPU0/0
# L    192.168.254.34/32 is directly connected, 00:09:38, MgmtEth0/RP0/CPU0/0
# C    198.51.100.0/24 is directly connected, 00:08:23, FourHundredGigE0/0/0/0
# L    198.51.100.1/32 is directly connected, 00:08:23, FourHundredGigE0/0/0/0
# O    203.0.113.0/24 [110/2] via 192.0.2.2, 00:07:41, FourHundredGigE0/0/0/1
# L    209.165.200.225/32 is directly connected, 00:08:23, Loopback0
# O    209.165.200.227/32 [110/2] via 192.0.2.2, 00:07:41, FourHundredGigE0/0/0/1
# O    209.165.200.229/32 [110/2] via 198.51.100.2, 00:07:43, FourHundredGigE0/0/0/0
# O    209.165.201.0/27 [110/2] via 198.51.100.2, 00:07:43, FourHundredGigE0/0/0/0
# RP/0/RP0/CPU0:P1#

# %% [markdown]
# ## <a name="step5"></a>Apply the QoS configurations on PE1

# %% [markdown]
# `The customer edge router has marked the DSCP bits as ef for the high priority video traffic. Play the below cell to configure the class-maps, policy-maps and apply the QoS configuration on the ingress interface of the PE1 router in order to the classify the traffic packets based on their DSCP value in the packet.`
# * `The ingress policy-map PE-INGRESS ensures that the incoming packets marked with EF for the DSCP field is set to traffic class 7 and marks the mpls exp bits to 7`
# * `The egress policy-map VIDEO-PRIORITY ensures that the packets with traffic class 7 are sent out through the high priority output queue of the egress interface. Hence these high-priority traffic packets will be forwarded with minimum delay`
# ![Topology](qos-pe.png)

# %%
print("Please wait. It may take 8-9 seconds to retrieve the information from the telnet console.")

loginpe1.write(('''
configure
class-map match-all DSCP-EF
match dscp ef
end-class-map
!
commit
root
!
policy-map PE-INGRESS
class DSCP-EF
set traffic-class 7
set mpls experimental imposition 7
!
class class-default
set traffic-class 0
!
end-policy-map
commit
root
!
interface FourHundredGigE0/0/0/0
service-policy input PE-INGRESS
commit
root
!
class-map match-any Video
match traffic-class 7
end-class-map
!
commit
root
policy-map VIDEO-PRIORITY
class Video
shape average 2 gbps
priority level 1
!
class class-default
!
end-policy-map
commit
root
!
interface FourHundredGigE0/0/0/1
service-policy output VIDEO-PRIORITY
commit
root
exit

''').encode('ascii'))
line = loginpe1.read_until(b'/r/n',8)
print(line.decode())
# Out:
# Please wait. It may take 8-9 seconds to retrieve the information from the telnet console.
#
# RP/0/RP0/CPU0:PE1#configure
# ce-policy input PE-INGRESS
# commit
# root
# !
# class-map match-any Video
# match traffic-class 7
# end-class-map
# !
# commit
# root
# policy-map VIDEO-PRIORITY
# class Video
# shape average 2 gbps
# priority level 1
# !
# class class-default
# !
# end-policy-map
# commit
# root
# !
# interface FourHundredGigE0/0/0/1
# service-policy output VIDEO-PRIORITY
# commit
# root
# exit
#
# Tue Apr 27 09:43:02.803 UTC
# RP/0/RP0/CPU0:PE1(config)#class-map match-all DSCP-EF
# RP/0/RP0/CPU0:PE1(config-cmap)#match dscp ef
# RP/0/RP0/CPU0:PE1(config-cmap)#end-class-map
# RP/0/RP0/CPU0:PE1(config)#!
# RP/0/RP0/CPU0:PE1(config)#commit
# Tue Apr 27 09:43:03.221 UTC
# RP/0/RP0/CPU0:PE1(config)#root
# RP/0/RP0/CPU0:PE1(config)#!
# RP/0/RP0/CPU0:PE1(config)#policy-map PE-INGRESS
# RP/0/RP0/CPU0:PE1(config-pmap)#class DSCP-EF
# RP/0/RP0/CPU0:PE1(config-pmap-c)#set traffic-class 7
# RP/0/RP0/CPU0:PE1(config-pmap-c)#set mpls experimental imposition 7
# RP/0/RP0/CPU0:PE1(config-pmap-c)#!
# RP/0/RP0/CPU0:PE1(config-pmap-c)#class class-default
# RP/0/RP0/CPU0:PE1(config-pmap-c)#set traffic-class 0
# RP/0/RP0/CPU0:PE1(config-pmap-c)#!
# RP/0/RP0/CPU0:PE1(config-pmap-c)#end-policy-map
# RP/0/RP0/CPU0:PE1(config)#commit
# Tue Apr 27 09:43:03.462 UTC
# RP/0/RP0/CPU0:PE1(config)#root
# RP/0/RP0/CPU0:PE1(config)#!
# RP/0/RP0/CPU0:PE1(config)#interface FourHundredGigE0/0/0/2
# RP/0/RP0/CPU0:PE1(config-if)#service-policy input PE-INGRESS
# RP/0/RP0/CPU0:PE1(config-if)#commit
# Tue Apr 27 09:43:03.670 UTC
# RP/0/RP0/CPU0:PE1(config-if)#root
# RP/0/RP0/CPU0:PE1(config)#!
# RP/0/RP0/CPU0:PE1(config)#class-map match-any Video
# RP/0/RP0/CPU0:PE1(config-cmap)#match traffic-class 7
# RP/0/RP0/CPU0:PE1(config-cmap)#end-class-map
# RP/0/RP0/CPU0:PE1(config)#!
# RP/0/RP0/CPU0:PE1(config)#commit
# Tue Apr 27 09:43:03.868 UTC
# RP/0/RP0/CPU0:PE1(config)#root
# RP/0/RP0/CPU0:PE1(config)#policy-map VIDEO-PRIORITY
# RP/0/RP0/CPU0:PE1(config-pmap)#class Video
# RP/0/RP0/CPU0:PE1(config-pmap-c)#shape average 2 gbps
# RP/0/RP0/CPU0:PE1(config-pmap-c)#priority level 1
# RP/0/RP0/CPU0:PE1(config-pmap-c)#!
# RP/0/RP0/CPU0:PE1(config-pmap-c)#class class-default
# RP/0/RP0/CPU0:PE1(config-pmap-c)#!
# RP/0/RP0/CPU0:PE1(config-pmap-c)#end-policy-map
# RP/0/RP0/CPU0:PE1(config)#commit
# Tue Apr 27 09:43:04.101 UTC
# RP/0/RP0/CPU0:PE1(config)#root
# RP/0/RP0/CPU0:PE1(config)#!
# RP/0/RP0/CPU0:PE1(config)#interface FourHundredGigE0/0/0/1
# RP/0/RP0/CPU0:PE1(config-if)#service-policy output VIDEO-PRIORITY
# RP/0/RP0/CPU0:PE1(config-if)#commit
# Tue Apr 27 09:43:04.312 UTC
# RP/0/RP0/CPU0:PE1(config-if)#root
# RP/0/RP0/CPU0:PE1(config)#exit
# RP/0/RP0/CPU0:PE1#
# RP/0/RP0/CPU0:PE1#

# %% [markdown]
# ## <a name="step6"></a>Apply the QoS configurations on other routers in the MPLS network

# %% [markdown]
# `Play the below cell to configure the class-maps, policy-maps and apply the QoS configuration on the ingress interface of the P1 router in order to the classify the incoming traffic packets based on their MPLS EXP value. Then in the egress interface, ensure that these delay-sensitive traffic gets high priority and assured bandwidth.`
# ![Topology](qos-core.png)

# %%
print("Please wait. It may take 8-9 seconds to retrieve the information from the telnet console.")

loginp1.write(('''
configure
class-map match-any EXP7
match mpls experimental topmost 7 
end-class-map
commit
root
!
policy-map CORE-INGRESS
class EXP7
set traffic-class 7
set mpls experimental imposition 7 

!
class class-default
set traffic-class 0
!
end-policy-map
commit
root
!
class-map match-any Video
match traffic-class 7
end-class-map
!
commit
root
!
policy-map VIDEO-PRIORITY
class Video
shape average 2 gbps
priority level 1
!
class class-default
!
end-policy-map
commit
root
!
interface FourHundredGigE0/0/0/0
service-policy input CORE-INGRESS
commit
root
!
interface FourHundredGigE0/0/0/1
service-policy output VIDEO-PRIORITY
commit
root
exit

''').encode('ascii'))
line = loginp1.read_until(b'/r/n',8)
print(line.decode())
# Out:
# Please wait. It may take 8-9 seconds to retrieve the information from the telnet console.
#
# ch-anyRP/0/RP0/CPU0:P1#configure
#  EXP7
# match mpls experimental topmost 7
# end-class-map
# commit
# root
# !
# policy-map CORE-INGRESS
# class EXP7
# set traffic-class 7
# set mpls experimental imposition 7
#
# !
# class class-default
# set traffic-class 0
# !
# end-policy-map
# commit
# root
# !
# class-map match-any Video
# match traffic-class 7
# end-class-map
# !
# commit
# root
# !
# policy-map VIDEO-PRIORITY
# class Video
# shape average 2 gbps
# priority level 1
# !
# class class-default
# !
# end-policy-map
# commit
# root
# !
# interface FourHundredGigE0/0/0/0
# service-policy output VIDEO-PRIORITY
# commit
# root
# !
# interface FourHundredGigE0/0/0/1
# service-policy input CORE-INGRESS
# commit
# root
# exit
#
# Tue Apr 27 09:43:31.985 UTC
# RP/0/RP0/CPU0:P1(config)#class-map match-any EXP7
# RP/0/RP0/CPU0:P1(config-cmap)#match mpls experimental topmost 7
# RP/0/RP0/CPU0:P1(config-cmap)#end-class-map
# RP/0/RP0/CPU0:P1(config)#commit
# Tue Apr 27 09:43:32.383 UTC
# RP/0/RP0/CPU0:P1(config)#root
# RP/0/RP0/CPU0:P1(config)#!
# RP/0/RP0/CPU0:P1(config)#policy-map CORE-INGRESS
# RP/0/RP0/CPU0:P1(config-pmap)#class EXP7
# RP/0/RP0/CPU0:P1(config-pmap-c)#set traffic-class 7
# RP/0/RP0/CPU0:P1(config-pmap-c)#set mpls experimental imposition 7
# RP/0/RP0/CPU0:P1(config-pmap-c)#
# RP/0/RP0/CPU0:P1(config-pmap-c)#!
# RP/0/RP0/CPU0:P1(config-pmap-c)#class class-default
# RP/0/RP0/CPU0:P1(config-pmap-c)#set traffic-class 0
# RP/0/RP0/CPU0:P1(config-pmap-c)#!
# RP/0/RP0/CPU0:P1(config-pmap-c)#end-policy-map
# RP/0/RP0/CPU0:P1(config)#commit
# Tue Apr 27 09:43:32.642 UTC
# RP/0/RP0/CPU0:P1(config)#root
# RP/0/RP0/CPU0:P1(config)#!
# RP/0/RP0/CPU0:P1(config)#class-map match-any Video
# RP/0/RP0/CPU0:P1(config-cmap)#match traffic-class 7
# RP/0/RP0/CPU0:P1(config-cmap)#end-class-map
# RP/0/RP0/CPU0:P1(config)#!
# RP/0/RP0/CPU0:P1(config)#commit
# Tue Apr 27 09:43:32.842 UTC
# RP/0/RP0/CPU0:P1(config)#root
# RP/0/RP0/CPU0:P1(config)#!
# RP/0/RP0/CPU0:P1(config)#policy-map VIDEO-PRIORITY
# RP/0/RP0/CPU0:P1(config-pmap)#class Video
# RP/0/RP0/CPU0:P1(config-pmap-c)#shape average 2 gbps
# RP/0/RP0/CPU0:P1(config-pmap-c)#priority level 1
# RP/0/RP0/CPU0:P1(config-pmap-c)#!
# RP/0/RP0/CPU0:P1(config-pmap-c)#class class-default
# RP/0/RP0/CPU0:P1(config-pmap-c)#!
# RP/0/RP0/CPU0:P1(config-pmap-c)#end-policy-map
# RP/0/RP0/CPU0:P1(config)#commit
# Tue Apr 27 09:43:33.081 UTC
# RP/0/RP0/CPU0:P1(config)#root
# RP/0/RP0/CPU0:P1(config)#!
# RP/0/RP0/CPU0:P1(config)#interface FourHundredGigE0/0/0/0
# RP/0/RP0/CPU0:P1(config-if)#service-policy output VIDEO-PRIORITY
# RP/0/RP0/CPU0:P1(config-if)#commit
# Tue Apr 27 09:43:33.280 UTC
# RP/0/RP0/CPU0:P1(config-if)#root
# RP/0/RP0/CPU0:P1(config)#!
# RP/0/RP0/CPU0:P1(config)#interface FourHundredGigE0/0/0/1
# RP/0/RP0/CPU0:P1(config-if)#service-policy input CORE-INGRESS
# RP/0/RP0/CPU0:P1(config-if)#commit
# Tue Apr 27 09:43:34.409 UTC
# RP/0/RP0/CPU0:P1(config-if)#root
# RP/0/RP0/CPU0:P1(config)#exit
# RP/0/RP0/CPU0:P1#
# RP/0/RP0/CPU0:P1#

# %% [markdown]
# ## <a name="step100"></a>Start traffic from TREX Traffic Generator

# %% [markdown]
# `The below cell is a call to a python function which logs into the Traffic Generator (TREX), performs the required configurations and then starts traffic across the SP network for an hour. Play this cell to start the traffic at 100pps.`
# ![traffic_flow](qos-traffic.png)

# %%
print("Please wait. Traffic Generator is starting....")

client1, client2, interact1, interact2 = generate_hipriority_traffic (trexipaddress, trexport)
# Out:
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_7.4)
# INFO:paramiko.transport:Authentication (publickey) failed.
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# INFO:paramiko.transport.sftp:[chan 0] sftp session closed.
# Last login: Tue Apr 27 09:33:17 2021
# [root@localhost ~]# ifconfig eth1 10.0.0.1 netmask 255.255.255.0 up; ifconfig et h2 10.1.1.1 netmask 255.255.255.0 up
# [root@localhost ~]# cd /opt/cisco/trex/latest/
# [root@localhost latest]# ./t-rex-64 -i
# Starting Scapy server....... Scapy server is started
# Trying to bind to vfio-pci ...
# Trying to compile and bind to igb_uio ...
# ERROR: We don't have precompiled igb_uio.ko module for your kernel version.
# Will try compiling automatically...
# Success.
#
# /usr/bin/python3 dpdk_nic_bind.py --bind=igb_uio 0000:00:04.0 0000:00:05.0
# The ports are bound/configured.
# Starting  TRex v2.89 please wait  ...
#  set driver name net_virtio
#  driver capability  :
#  set dpdk queues mode to ONE_QUE
#  Number of ports found: 2
# zmq publisher at: tcp://*:4500
#  wait 1 sec
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_7.4)
# INFO:paramiko.transport:Authentication (publickey) failed.
# INFO:paramiko.transport:Authentication (password) successful!
# Last login: Tue Apr 27 09:43:45 2021 from gateway
# [root@localhost ~]# cd /opt/cisco/trex/latest/
# [root@localhost latest]# ./trex-console
# start -f stl/dscp_traffic1.py -d 1h -m 100pps -p 0
#
# Using 'python3' as Python interpeter
#
#
# Connecting to RPC server on localhost:4501                   [SUCCESS]
#
#
# Connecting to publisher server on localhost:4500             [SUCCESS]
#
#
# Acquiring ports [0, 1]:                                      [SUCCESS]
#
#
# Server Info:
#
# Server version:   v2.89 @ STL
# Server mode:      Stateless
# Server CPU:       1 x VXR
# Ports count:      2 x 100.0Gbps @ Virtio network device
#
# -=TRex Console v3.0=-
#
# Type 'help' or '?' for supported actions
#
# trex>start -f stl/dscp_traffic1.py -d 1h -m 100pps -p 0

# %% [markdown]
# ## <a name="step7"></a>Verify the QoS configurations using show commands
# `Play the below cell to check the the outputs of the interface counters and the policy-map on the routers. The interface counters show the number of packets incoming or outgoing from the interface. And the policy-map counters show the number of packets for which the QoS is being applied. In the below show command outputs verify that the packet counters are incrementing in class DSCP-EF in the ingress policy-map and in class Video in the egress policy-map.`

# %%
print("Please wait. It may take 4-5 seconds to retrieve the information from the telnet console.")

# Check the input and output policies applied on PE1 router.
loginpe1.write(('''
show interface FourHundredGigE0/0/0/0 accounting
show interface FourHundredGigE0/0/0/1 accounting
show policy-map interface FourHundredGigE0/0/0/0
show policy-map interface FourHundredGigE0/0/0/1
''').encode('ascii'))
line = loginpe1.read_until(b'/r/n',4)
print("***** LIVE OUTPUT FROM TELNET CONSOLE OF PE1 *****")
print(line.decode())
# Out:
# Please wait. It may take 4-5 seconds to retrieve the information from the telnet console.
# ***** LIVE OUTPUT FROM TELNET CONSOLE OF PE1 *****
#
# RP/0/RP0/CPU0:PE1#show interface FourHundredGigE0/0/0/2 accounting
# how interface FourHundredGigE0/0/0/1 accounting
# show policy-map interface FourHundredGigE0/0/0/2
# show policy-map interface FourHundredGigE0/0/0/1
# Tue Apr 27 09:44:55.260 UTC
# FourHundredGigE0/0/0/2
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST             5613                0            0                0
#   ARP                         3              180            2               84
#
#
# RP/0/RP0/CPU0:PE1#show interface FourHundredGigE0/0/0/1 accounting
# Tue Apr 27 09:44:55.383 UTC
# FourHundredGigE0/0/0/1
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST               31                0            0                0
#   MPLS                        0                0         5624            22496
#   ARP                         1               74            2               84
#
#
# RP/0/RP0/CPU0:PE1#show policy-map interface FourHundredGigE0/0/0/2
# Tue Apr 27 09:44:55.481 UTC
#
# FourHundredGigE0/0/0/2 input: PE-INGRESS
#
# Class DSCP-EF
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                2621/0                    0
#     Transmitted         :                2621/0                    0
#     Total Dropped       :                   0/0                    0
# Class class-default
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                   0/0                    0
#     Transmitted         :                   0/0                    0
#     Total Dropped       :                   0/0                    0
# Policy Bag Stats time: 1619516665735  [Local Time: 04/27/21 09:44:25.735]
# FourHundredGigE0/0/0/2 direction output: Service Policy not installed
# RP/0/RP0/CPU0:PE1#show policy-map interface FourHundredGigE0/0/0/1
# Tue Apr 27 09:44:55.569 UTC
# FourHundredGigE0/0/0/1 direction input: Service Policy not installed
#
# FourHundredGigE0/0/0/1 output: VIDEO-PRIORITY
#
# Class Video
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                2706/0                    0
#     Transmitted         :                2706/0                    0
#     Total Dropped       :                   0/0                    0
#   Queueing statistics
#     Queue ID                             : 463
#     Taildropped(packets/bytes)           : 0/0
# Class class-default
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                   0/0                    0
#     Transmitted         :                   0/0                    0
#     Total Dropped       :                   0/0                    0
# Policy Bag Stats time: 1619516665735  [Local Time: 04/27/21 09:44:25.735]
# RP/0/RP0/CPU0:PE1#

# %% [markdown]
# `In the below show command outputs verify that the packet counters are incrementing in class EXP7 in the ingress policy-map and in class Video in the egress policy-map. This shows that even in subsequent routers in the MPLS network, delay-sensitive traffic can be given high priority.`

# %%
print("Please wait. It may take 4-5 seconds to retrieve the information from the telnet console.")

loginp1.write(('''
show interface FourHundredGigE0/0/0/0 accounting
show interface FourHundredGigE0/0/0/1 accounting
show policy-map interface FourHundredGigE0/0/0/0
show policy-map interface FourHundredGigE0/0/0/1
''').encode('ascii'))
line = loginp1.read_until(b'/r/n',4)
print("***** LIVE OUTPUT FROM TELNET CONSOLE OF P1 *****")
print(line.decode())
# Out:
# ***** LIVE OUTPUT FROM TELNET CONSOLE OF P1 *****
#
# RP/0/RP0/CPU0:P1#show interface FourHundredGigE0/0/0/1 accounting
# Tue Apr 27 09:45:05.191 UTC
# FourHundredGigE0/0/0/1
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST               33                0            0                0
#   MPLS                     6548                0            0                0
#   ARP                         2              148            2               84
#
#
# RP/0/RP0/CPU0:P1#show interface FourHundredGigE0/0/0/0 accounting
# Tue Apr 27 09:45:05.280 UTC
# FourHundredGigE0/0/0/0
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST               34                0         6556            26224
#   ARP                         1               74            1               42
#
#
# RP/0/RP0/CPU0:P1#show policy-map interface FourHundredGigE0/0/0/1
# Tue Apr 27 09:45:05.359 UTC
#
# FourHundredGigE0/0/0/1 input: CORE-INGRESS
#
# Class EXP7
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                2346/0                    0
#     Transmitted         :                2346/0                    0
#     Total Dropped       :                   0/0                    0
# Class class-default
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                   0/0                    0
#     Transmitted         :                   0/0                    0
#     Total Dropped       :                   0/0                    0
# Policy Bag Stats time: 1619516663610  [Local Time: 04/27/21 09:44:23.610]
# FourHundredGigE0/0/0/1 direction output: Service Policy not installed
# RP/0/RP0/CPU0:P1#show policy-map interface FourHundredGigE0/0/0/0
# Tue Apr 27 09:45:05.431 UTC
# FourHundredGigE0/0/0/0 direction input: Service Policy not installed
#
# FourHundredGigE0/0/0/0 output: VIDEO-PRIORITY
#
# Class Video
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                2262/0                    0
#     Transmitted         :                2262/0                    0
#     Total Dropped       :                   0/0                    0
#   Queueing statistics
#     Queue ID                             : 455
#     Taildropped(packets/bytes)           : 0/0
# Class class-default
#   Classification statistics          (packets/bytes)     (rate - kbps)
#     Matched             :                   0/0                    0
#     Transmitted         :                   0/0                    0
#     Total Dropped       :                   0/0                    0
# Policy Bag Stats time: 1619516663610  [Local Time: 04/27/21 09:44:23.610]
# RP/0/RP0/CPU0:P1#

# %% [markdown]
# `Close the telnet consoles and bring down the emulator after you are done with testing.`

# %%
loginpe1.close()
loginpe2.close()
logince1.close()
logince2.close()
loginp1.close()
client1.close()
client2.close()

# %%
sim.stop()
# Out:
# INFO:pyvxr.vxr:Stopping sim on host localhost (dir /nobackup/vxr/pyvxr/lrrf79dilr)
# INFO:pyvxr.sim:Stopping previous simulation (if any)

# %%
sim.clean()
# Clean up sim scratch space
shutil.rmtree(sim_dir)
# Out:
# INFO:pyvxr.vxr:Cleaning sim on host localhost (dir /nobackup/vxr/pyvxr/lrrf79dilr)
# INFO:pyvxr.sim:Stopping previous simulation (if any)
# INFO:pyvxr.sim:Cleaning previous simulation (if any)

# %% [markdown]
# Hope you now have a good idea on using QoS policies to ensure that high-priority traffic is forwarded through the network with minimum delay. If you have any comments or suggestions about this notebook, please reach out to sasamuel@cisco.com. We look forward to your feedback.
